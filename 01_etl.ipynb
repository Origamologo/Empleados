# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # ANÁLISIS EXPLORATORIO Y LIMPIEZA
#
# Comenzaremos transformado el csv en dataframe para analizarlo y proceder a su limpieza

# %%
df = pd.read_csv("/home/miguel/Documents/Python/Empleados/data/empleados.csv", index_col = 0)

# %%
pd.options.display.max_columns = None
df.head(10)
# Out:
#   Age Attrition     BusinessTravel DailyRate                Department  \
# 0  51        No                NaN    684,0$                       NaN
# 1  52        No                NaN    699,0$                       NaN
# 2  42        No      travel_rarely    532,0$   Research & Development
# 3  47        No      travel_rarely    359,0$                       NaN
# 4  46        No                NaN   1319,0$                       NaN
# 5  48        No                NaN    117,0$   Research & Development
# 6  59        No                NaN   1435,0$                       NaN
# 7  42        No      travel_rarely    635,0$                       NaN
# 8  41        No                NaN   1276,0$                       NaN
# 9  41        No  travel_frequently    840,0$                       NaN
#
#    DistanceFromHome  Education    EducationField  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
# 5                22          3           Medical              1
# 6                25          3     Life Sciences              1
# 7                 1          1               NaN              1
# 8                 2          5               NaN              1
# 9                 9          3               NaN              1
#
#   employeenumber  EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  \
# 0          162,0                        1       0         51               3
# 1          259,0                        3       0         65               2
# 2          319,0                        3       0         58               3
# 3            NaN                        1       1         82               3
# 4            NaN                        1       1         45               4
# 5         1900,0                        4       1         58               3
# 6           81,0                        1       1         99               3
# 7          387,0                        2       0         99               3
# 8            NaN                        2       1         91               3
# 9          999,0                        1       0         64               3
#
#    JobLevel              JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0         5   resEArch DIREcToR                 3           NaN       19537,0
# 1         5             ManAGeR                 3           NaN       19999,0
# 2         5             ManaGER                 4       Married       19232,0
# 3         4   ReseArCH DIrECtOr                 3       Married       17169,0
# 4         4     sAleS EXECUtIve                 1      Divorced           NaN
# 5         4             MANAger                 4           NaN       17174,0
# 6         3     Sales ExeCutIVe                 1           NaN           NaN
# 7         2     Sales eXEcUTiVe                 3       Married           NaN
# 8         4             mANAGEr                 1       Married       16595,0
# 9         5   reSEaRCH DIrectoR                 3           NaN           NaN
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
# 2         4933                   1    NaN       No                 11
# 3        26703                   3      Y      NaN                 19
# 4         7739                   2      Y       No                 12
# 5         2437                   3    NaN       No                 11
# 6         2354                   7      Y      NaN                 11
# 7        24532                   1    NaN       No                 25
# 8         5626                   7    NaN       No                 16
# 9         3735                   2    NaN       No                 17
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2           NaN                 2
# 4               3,0                         4           NaN                 1
# 5               3,0                         2           NaN                 1
# 6               3,0                         4           NaN                 0
# 7               4,0                         3           NaN                 0
# 8               3,0                         2           NaN                 1
# 9               3,0                         2           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
# 5               NaN                      3             3,0              22
# 6              28,0                      3             2,0              21
# 7              20,0                      3             3,0              20
# 8              22,0                      2             3,0              18
# 9              21,0                      2             4,0              18
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
# 3                NaN                        5                     6
# 4                NaN                        2                     8
# 5                NaN                        4                     7
# 6                NaN                        7                     9
# 7                NaN                       11                     6
# 8                NaN                       11                     8
# 9                NaN                        0                    11
#
#   SameAsMonthlyIncome  DateBirth       Salary  \
# 0             19537,0       1972  1000000000$
# 1             19999,0       1971  1000000000$
# 2             19232,0       1981  1000000000$
# 3             17169,0       1976  1000000000$
# 4                 NaN       1977  1000000000$
# 5             17174,0       1975  1000000000$
# 6                 NaN       1964  1000000000$
# 7                 NaN       1981  1000000000$
# 8             16595,0       1982  1000000000$
# 9                 NaN       1982  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0
# 5   MANAger  -  Research & Development              NaN        Yes
# 6                                   NaN             NaN       True
# 7                                   NaN             NaN          0
# 8                                   NaN             NaN       True
# 9                                   NaN             NaN          0

# %%
df.shape
# Out:
# (1614, 41)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %% [markdown]
# Vamos a cambiar el nombre de las columnas a snake_case en mayúsculas.

# %%
columns_snake = ['Age', 'Attrition', 'Business_travel', 'Daily_rate', 'Department',
       'Distance_from_home', 'Education', 'Education_field', 'Employee_count',
       'Employee_number', 'Environment_Satisfaction', 'Gender', 'Hourly_Rate',
       'Job_Involvement', 'Job_Level', 'Job_Role', 'Job_Satisfaction',
       'Marital_Status', 'Monthly_Income', 'Monthly_Rate', 'NUM_COMPANIES_WORKED',
       'Over_18', 'Over_Time', 'Percent_Salary_Hike', 'Performance_Rating',
       'Relationship_Satisfaction', 'Standard_Hours', 'Stock_Option_Level',
       'TOTAL_WORKING_YEARS', 'Training_Times_Last_Year', 'WORK_LIFE_BALANCE',
       'Years_At_Company', 'Years_In_Current_Role', 'Years_Since_Last_Promotion',
       'YEARS_WITH_CURR_MANAGER', 'Same_As_Monthly_Income', 'Date_Birth', 'Salary',
       'Role_Departament', 'NUMBER_CHILDREN', 'Remote_Work']

# %%
columns_upper = [i.upper() for i in columns_snake]

# %%
df.columns = columns_upper

# %%
df.head()
# Out:
#   AGE ATTRITION BUSINESS_TRAVEL DAILY_RATE                DEPARTMENT  \
# 0  51        No             NaN     684,0$                       NaN
# 1  52        No             NaN     699,0$                       NaN
# 2  42        No   travel_rarely     532,0$   Research & Development
# 3  47        No   travel_rarely     359,0$                       NaN
# 4  46        No             NaN    1319,0$                       NaN
#
#    DISTANCE_FROM_HOME  EDUCATION   EDUCATION_FIELD  EMPLOYEE_COUNT  \
# 0                   6          3               NaN               1
# 1                   1          4     Life Sciences               1
# 2                   4          2  Technical Degree               1
# 3                   2          4           Medical               1
# 4                   3          3  Technical Degree               1
#
#   EMPLOYEE_NUMBER  ENVIRONMENT_SATISFACTION  GENDER HOURLY_RATE  \
# 0           162,0                         1       0          51
# 1           259,0                         3       0          65
# 2           319,0                         3       0          58
# 3             NaN                         1       1          82
# 4             NaN                         1       1          45
#
#    JOB_INVOLVEMENT  JOB_LEVEL             JOB_ROLE  JOB_SATISFACTION  \
# 0                3          5   resEArch DIREcToR                  3
# 1                2          5             ManAGeR                  3
# 2                3          5             ManaGER                  4
# 3                3          4   ReseArCH DIrECtOr                  3
# 4                4          4     sAleS EXECUtIve                  1
#
#   MARITAL_STATUS MONTHLY_INCOME  MONTHLY_RATE  NUM_COMPANIES_WORKED OVER_18  \
# 0            NaN        19537,0          6462                     7       Y
# 1            NaN        19999,0          5678                     0     NaN
# 2        Married        19232,0          4933                     1     NaN
# 3        Married        17169,0         26703                     3       Y
# 4       Divorced            NaN          7739                     2       Y
#
#   OVER_TIME  PERCENT_SALARY_HIKE PERFORMANCE_RATING  \
# 0        No                   13                3,0
# 1       NaN                   14                3,0
# 2        No                   11                3,0
# 3       NaN                   19                3,0
# 4        No                   12                3,0
#
#    RELATIONSHIP_SATISFACTION STANDARD_HOURS  STOCK_OPTION_LEVEL  \
# 0                          3            NaN                   0
# 1                          1            NaN                   1
# 2                          4            NaN                   0
# 3                          2            NaN                   2
# 4                          4            NaN                   1
#
#   TOTAL_WORKING_YEARS  TRAINING_TIMES_LAST_YEAR WORK_LIFE_BALANCE  \
# 0                 NaN                         5               3,0
# 1                34,0                         5               3,0
# 2                22,0                         3               NaN
# 3                 NaN                         2               NaN
# 4                 NaN                         5               3,0
#
#    YEARS_AT_COMPANY YEARS_IN_CURRENT_ROLE  YEARS_SINCE_LAST_PROMOTION  \
# 0                20                   NaN                          15
# 1                33                   NaN                          11
# 2                22                   NaN                          11
# 3                20                   NaN                           5
# 4                19                   NaN                           2
#
#    YEARS_WITH_CURR_MANAGER SAME_AS_MONTHLY_INCOME  DATE_BIRTH       SALARY  \
# 0                       15                19537,0        1972  1000000000$
# 1                        9                19999,0        1971  1000000000$
# 2                       15                19232,0        1981  1000000000$
# 3                        6                17169,0        1976  1000000000$
# 4                        8                    NaN        1977  1000000000$
#
#                        ROLE_DEPARTAMENT  NUMBER_CHILDREN REMOTE_WORK
# 0                                   NaN              NaN         Yes
# 1                                   NaN              NaN           1
# 2   ManaGER  -  Research & Development               NaN           1
# 3                                   NaN              NaN       False
# 4                                   NaN              NaN           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AGE                         1614 non-null   object
#  1   ATTRITION                   1614 non-null   object
#  2   BUSINESS_TRAVEL             842 non-null    object
#  3   DAILY_RATE                  1614 non-null   object
#  4   DEPARTMENT                  302 non-null    object
#  5   DISTANCE_FROM_HOME          1614 non-null   int64
#  6   EDUCATION                   1614 non-null   int64
#  7   EDUCATION_FIELD             869 non-null    object
#  8   EMPLOYEE_COUNT              1614 non-null   int64
#  9   EMPLOYEE_NUMBER             1183 non-null   object
#  10  ENVIRONMENT_SATISFACTION    1614 non-null   int64
#  11  GENDER                      1614 non-null   int64
#  12  HOURLY_RATE                 1614 non-null   object
#  13  JOB_INVOLVEMENT             1614 non-null   int64
#  14  JOB_LEVEL                   1614 non-null   int64
#  15  JOB_ROLE                    1614 non-null   object
#  16  JOB_SATISFACTION            1614 non-null   int64
#  17  MARITAL_STATUS              963 non-null    object
#  18  MONTHLY_INCOME              771 non-null    object
#  19  MONTHLY_RATE                1614 non-null   int64
#  20  NUM_COMPANIES_WORKED        1614 non-null   int64
#  21  OVER_18                     713 non-null    object
#  22  OVER_TIME                   938 non-null    object
#  23  PERCENT_SALARY_HIKE         1614 non-null   int64
#  24  PERFORMANCE_RATING          1419 non-null   object
#  25  RELATIONSHIP_SATISFACTION   1614 non-null   int64
#  26  STANDARD_HOURS              419 non-null    object
#  27  STOCK_OPTION_LEVEL          1614 non-null   int64
#  28  TOTAL_WORKING_YEARS         1088 non-null   object
#  29  TRAINING_TIMES_LAST_YEAR    1614 non-null   int64
#  30  WORK_LIFE_BALANCE           1506 non-null   object
#  31  YEARS_AT_COMPANY            1614 non-null   int64
#  32  YEARS_IN_CURRENT_ROLE       34 non-null     object
#  33  YEARS_SINCE_LAST_PROMOTION  1614 non-null   int64
#  34  YEARS_WITH_CURR_MANAGER     1614 non-null   int64
#  35  SAME_AS_MONTHLY_INCOME      771 non-null    object
#  36  DATE_BIRTH                  1614 non-null   int64
#  37  SALARY                      1614 non-null   object
#  38  ROLE_DEPARTAMENT            302 non-null    object
#  39  NUMBER_CHILDREN             0 non-null      float64
#  40  REMOTE_WORK                 1614 non-null   object
# dtypes: float64(1), int64(18), object(22)
# memory usage: 529.6+ KB

# %% [markdown]
# ## Columnas numéricas

# %% [markdown]
# Parece haber bastantes columnas con el tipo de dato erroneo, por ejemplo 'AGE' debería de ser un entero. También 'DAILY_RATE' y ', 'SALARY', que además tiene un símbolo de dolar que tendremos que eliminar.
#
# Vamos a comprobar los valores únicos de estas columnas y a solucionar este problema de tipos de dato. También a eliminar las columnas 'SAME_AS_MONTHLY_INCOME', que es redundante, y 'EMPLOYEE_NUMBER', que contiene nulos y nos resulta útil.

# %%
df_types = df.drop(['SAME_AS_MONTHLY_INCOME', 'EMPLOYEE_NUMBER'], axis=1)

# %%
integer = ['AGE', 'HOURLY_RATE', 'STANDARD_HOURS', 'TOTAL_WORKING_YEARS', 'WORK_LIFE_BALANCE', 'YEARS_IN_CURRENT_ROLE', 'NUMBER_CHILDREN']
float = ['MONTHLY_INCOME', 'PERFORMANCE_RATING']
dollar = ['DAILY_RATE', 'SALARY']

# %%
print('\n'.join(f"{i} {df_types[i].unique()}" for i in integer))
# Out:
# AGE ['51' '52' '42' '47' '46' '48' '59' '41' '56' '38' '55' '40' '58' '35'
#  '45' '33' '36' '34' 'forty-seven' '53' '43' '60' '32' '37' '49' '39' '50'
#  '44' '30' 'fifty-eight' '29' '31' '54' '57' '27' 'thirty-six' '28' '26'
#  'fifty-five' '25' 'fifty-two' 'thirty-one' '24' 'thirty' '23' '22' '21'
#  '20' 'twenty-six' '19' 'thirty-seven' '18' 'thirty-two' 'twenty-four']
# HOURLY_RATE ['51' '65' '58' '82' '45' '99' '91' '64' '55' '68' '49' '61' '79' '31'
#  '69' '48' '80' '74' '98' '59' '33' '56' '66' '57' '53' '87' '81' '84'
#  '32' '41' '92' '47' 'Not Available' '43' '86' '30' '42' '88' '96' '67'
#  '62' '72' '78' '89' '52' '50' '90' '37' '94' '76' '60' '46' '83' '100'
#  '40' '97' '54' '75' '39' '85' '63' '44' '93' '36' '35' '73' '71' '70'
#  '38' '77' '95' '34']
# STANDARD_HOURS [nan '80,0']
# TOTAL_WORKING_YEARS [nan '34,0' '22,0' '28,0' '20,0' '21,0' '33,0' '40,0' '18,0' '25,0' '15,0'
#  '17,0' '26,0' '16,0' '24,0' '14,0' '23,0' '27,0' '19,0' '11,0' '38,0'
#  '37,0' '13,0' '12,0' '29,0' '10,0' '36,0' '35,0' '9,0' '31,0' '32,0'
#  '8,0' '7,0' '30,0' '6,0' '5,0' '4,0' '3,0' '2,0' '1,0' '0,0']
# WORK_LIFE_BALANCE ['3,0' nan '2,0' '4,0' '1,0']
# YEARS_IN_CURRENT_ROLE [nan '13,0' '12,0' '11,0' '7,0' '6,0' '4,0' '3,0' '2,0' '1,0' '0,0']
# NUMBER_CHILDREN [nan]

# %%
print('\n'.join(f"{i} {df_types[i].unique()}" for i in float))
# Out:
# MONTHLY_INCOME ['19537,0' '19999,0' '19232,0' '17169,0' nan '17174,0' '16595,0' '19973,0'
#  '13402,0' '13206,0' '19545,0' '18041,0' '19246,0' '10748,0' '16752,0'
#  '6201,0' '19845,0' '4001,0' '10447,0' '16064,0' '3210,0' '10266,0'
#  '10475,0' '6162,0' '4721,0' '4615,0' '16959,0' '10306,0' '5406,0'
#  '5902,0' '10855,0' '5914,0' '6646,0' '13973,0' '13320,0' '6687,0'
#  '4735,0' '13872,0' '19045,0' '16015,0' '9613,0' '11510,0' '4306,0'
#  '17046,0' '5067,0' '3692,0' '19847,0' '2308,0' '5747,0' '10422,0'
#  '6347,0' '2348,0' '3072,0' '12490,0' '8020,0' '17068,0' '8943,0'
#  '19272,0' '5577,0' '2691,0' '7403,0' '8823,0' '3579,0' '17779,0'
#  '18213,0' '13577,0' '19190,0' '17123,0' '19187,0' '10008,0' '7988,0'
#  '7083,0' '4723,0' '3407,0' '2929,0' '12031,0' '15427,0' '5126,0' '9619,0'
#  '5010,0' '19033,0' '10400,0' '2793,0' '5674,0' '19197,0' '8412,0'
#  '3348,0' '5309,0' '7654,0' '12808,0' '6586,0' '2519,0' '17099,0'
#  '13120,0' '3131,0' '4444,0' '6674,0' '9852,0' '17861,0' '7446,0'
#  '13757,0' '16598,0' '4285,0' '10124,0' '9714,0' '9924,0' '11245,0'
#  '3069,0' '9241,0' '6472,0' '3055,0' '8321,0' '3143,0' '8578,0' '4197,0'
#  '9888,0' '13341,0' '5677,0' '2909,0' '9526,0' '6825,0' '4424,0' '5441,0'
#  '6074,0' '6146,0' '6172,0' '4668,0' '5605,0' '4319,0' '3564,0' '6261,0'
#  '6804,0' '19436,0' '5828,0' '2455,0' '5055,0' '4682,0' '5257,0' '2119,0'
#  '5974,0' '3034,0' '13212,0' '8392,0' '4051,0' '4805,0' '2741,0' '5337,0'
#  '9434,0' '5396,0' '11159,0' '4960,0' '8793,0' '19189,0' '2216,0'
#  '11713,0' '5304,0' '11103,0' '6632,0' '7587,0' '4335,0' '5980,0' '4244,0'
#  '5228,0' '2700,0' '2366,0' '2329,0' '4294,0' '6725,0' '10325,0' '4447,0'
#  '10845,0' '5472,0' '6385,0' '7525,0' '3660,0' '8740,0' '13499,0' '3491,0'
#  '5220,0' '10252,0' '19740,0' '6209,0' '7094,0' '4534,0' '8500,0' '4639,0'
#  '5363,0' '4081,0' '3578,0' '17328,0' '10793,0' '10851,0' '10466,0'
#  '2362,0' '6439,0' '5769,0' '4385,0' '4066,0' '5206,0' '2655,0' '2570,0'
#  '4502,0' '4968,0' '5147,0' '2718,0' '3539,0' '5468,0' '5813,0' '9667,0'
#  '5154,0' '5675,0' '7314,0' '5098,0' '13570,0' '6712,0' '9991,0' '10248,0'
#  '10938,0' '2593,0' '11878,0' '8095,0' '16856,0' '4537,0' '17924,0'
#  '4014,0' '12742,0' '3376,0' '10482,0' '4249,0' '6549,0' '14411,0'
#  '19586,0' '8237,0' '3211,0' '16704,0' '4774,0' '4568,0' '5993,0' '6499,0'
#  '3452,0' '6397,0' '2725,0' '3622,0' '6180,0' '6274,0' '4381,0' '2559,0'
#  '5488,0' '2514,0' '3196,0' '3420,0' '4087,0' '5368,0' '12936,0' '4221,0'
#  '4963,0' '4200,0' '5006,0' '7639,0' '6502,0' '13525,0' '6349,0' '6380,0'
#  '3102,0' '4556,0' '4230,0' '4859,0' '6322,0' '10761,0' '2973,0' '5204,0'
#  '17399,0' '16885,0' '4323,0' '5155,0' '2936,0' '18789,0' '4883,0'
#  '2029,0' '2996,0' '9278,0' '4162,0' '8853,0' '4876,0' '2141,0' '7756,0'
#  '3936,0' '6842,0' '3989,0' '4930,0' '3702,0' '2705,0' '4448,0' '2379,0'
#  '5487,0' '2810,0' '8938,0' '9936,0' '5454,0' '18740,0' '5473,0' '13503,0'
#  '13549,0' '18172,0' '2774,0' '9439,0' '5265,0' '3815,0' '2389,0' '4000,0'
#  '17584,0' '5661,0' '4869,0' '4649,0' '10496,0' '2768,0' '3408,0' '3755,0'
#  '2187,0' '4258,0' '5326,0' '5485,0' '2782,0' '17639,0' '6062,0' '6288,0'
#  '3424,0' '4194,0' '2532,0' '5666,0' '13726,0' '4107,0' '3597,0' '4115,0'
#  '6272,0' '2517,0' '3904,0' '9204,0' '4373,0' '2064,0' '2430,0' '4877,0'
#  '3760,0' '2013,0' '2974,0' '2766,0' '3377,0' '4213,0' '6513,0' '4284,0'
#  '2226,0' '5561,0' '2144,0' '5373,0' '2897,0' '5321,0' '5410,0' '4850,0'
#  '2001,0' '4404,0' '3944,0' '2960,0' '18947,0' '6465,0' '2683,0' '2014,0'
#  '3441,0' '13664,0' '5021,0' '18844,0' '4739,0' '10650,0' '4317,0'
#  '2024,0' '3058,0' '3929,0' '4425,0' '2328,0' '2657,0' '5940,0' '2622,0'
#  '3212,0' '2911,0' '6931,0' '2176,0' '3230,0' '18665,0' '2789,0' '6410,0'
#  '4941,0' '3983,0' '2904,0' '2696,0' '2174,0' '6755,0' '10965,0' '2543,0'
#  '19406,0' '6538,0' '2258,0' '2218,0' '2654,0' '11935,0' '2546,0' '3894,0'
#  '4262,0' '10527,0' '2400,0' '3681,0' '3447,0' '19513,0' '2659,0' '8847,0'
#  '2045,0' '4851,0' '8120,0' '4577,0' '5405,0' '3708,0' '13770,0' '2297,0'
#  '2450,0' '4342,0' '2572,0' '6500,0' '3149,0' '5324,0' '4382,0' '2553,0'
#  '5933,0' '4403,0' '10934,0' '2022,0' '4256,0' '3580,0' '2899,0' '5562,0'
#  '2377,0' '2404,0' '2799,0' '2811,0' '4377,0' '4240,0' '4227,0' '3917,0'
#  '4969,0' '2042,0' '2821,0' '9957,0' '2207,0' '2070,0' '2791,0' '8224,0'
#  '2610,0' '5731,0' '2539,0' '2376,0' '19081,0' '2743,0' '4538,0' '3867,0'
#  '2080,0' '2096,0' '4627,0' '2302,0' '5071,0' '10596,0' '5467,0' '2394,0'
#  '3629,0' '9362,0' '3229,0' '16422,0' '5647,0' '4400,0' '2066,0' '5486,0'
#  '3162,0' '6651,0' '4898,0' '3180,0' '11244,0' '4069,0' '6392,0' '4855,0'
#  '3312,0' '3117,0' '15202,0' '2580,0' '2166,0' '4374,0' '5505,0' '2587,0'
#  '15972,0' '2305,0' '3433,0' '3477,0' '3907,0' '3445,0' '2760,0' '6294,0'
#  '13116,0' '3591,0' '2105,0' '3902,0' '2662,0' '2062,0' '5507,0' '8103,0'
#  '3978,0' '5399,0' '10448,0' '4440,0' '2660,0' '3375,0' '2269,0' '4787,0'
#  '2809,0' '10854,0' '2571,0' '6142,0' '2496,0' '3419,0' '2501,0' '2566,0'
#  '3920,0' '13964,0' '6540,0' '2244,0' '16184,0' '4233,0' '14814,0'
#  '17159,0' '2318,0' '3617,0' '2684,0' '19237,0' '4422,0' '2552,0' '2678,0'
#  '5171,0' '11916,0' '9380,0' '5878,0' '2468,0' '4127,0' '2148,0' '3886,0'
#  '6667,0' '2090,0' '2086,0' '1951,0' '3022,0' '9724,0' '3388,0' '3038,0'
#  '2322,0' '2926,0' '4505,0' '2835,0' '6553,0' '6673,0' '13591,0' '2177,0'
#  '19517,0' '19202,0' '10048,0' '2723,0' '6644,0' '3161,0' '1420,0'
#  '1200,0' '5238,0' '9985,0' '15992,0' '2370,0' '6781,0' '6653,0' '2851,0'
#  '5258,0' '2476,0' '2285,0' '3448,0' '4558,0' '1702,0' '2564,0' '5070,0'
#  '3780,0' '9824,0' '1878,0' '2340,0' '2127,0' '2033,0' '9602,0' '16627,0'
#  '2083,0' '1009,0' '7861,0' '2642,0' '5121,0' '2694,0' '5094,0' '2274,0'
#  '2314,0' '2380,0' '2008,0' '10552,0' '2259,0' '2413,0' '2121,0' '2479,0'
#  '13194,0' '4163,0' '2600,0' '18303,0' '4777,0' '1052,0' '2461,0' '2596,0'
#  '4728,0' '7351,0' '4766,0' '2827,0' '2853,0' '2290,0' '2107,0' '2210,0'
#  '13191,0' '18265,0' '1118,0' '2372,0' '2838,0' '18061,0' '1611,0'
#  '4768,0' '1274,0' '2561,0' '1563,0' '6388,0' '8376,0' '4841,0' '2074,0'
#  '2972,0' '6815,0' '2690,0' '17567,0' '1569,0' '4187,0' '3306,0' '1393,0'
#  '10883,0' '2862,0' '6735,0' '9756,0' '5294,0' '2437,0' '4071,0' '2956,0'
#  '4648,0' '2804,0' '2439,0' '2856,0' '2933,0' '1091,0' '5151,0' '2863,0'
#  '2858,0' '1129,0' '19431,0']
# PERFORMANCE_RATING ['3,0' '4,0' nan]

# %%
print('\n'.join(f"{i} {df_types[i].unique()}" for i in dollar))
# Out:
# DAILY_RATE ['684,0$' '699,0$' '532,0$' '359,0$' '1319,0$' '117,0$' '1435,0$' '635,0$'
#  '1276,0$' '840,0$' '247,0$' '1369,0$' '201,0$' '1360,0$' '692,0$'
#  '1398,0$' '286,0$' '1402,0$' '819,0$' '884,0$' '1238,0$' '515,0$'
#  '1223,0$' '202,0$' '928,0$' '607,0$' '266,0$' '429,0$' '589,0$' 'nan$'
#  '1180,0$' '1282,0$' '776,0$' '665,0$' '526,0$' '1034,0$' '1403,0$'
#  '1499,0$' '580,0$' '859,0$' '263,0$' '1376,0$' '885,0$' '1003,0$'
#  '1321,0$' '394,0$' '1372,0$' '1333,0$' '228,0$' '737,0$' '823,0$'
#  '667,0$' '301,0$' '573,0$' '1329,0$' '630,0$' '1063,0$' '1017,0$'
#  '1296,0$' '939,0$' '1355,0$' '1448,0$' '200,0$' '1202,0$' '404,0$'
#  '208,0$' '813,0$' '465,0$' '1189,0$' '1001,0$' '1394,0$' '161,0$'
#  '288,0$' '682,0$' '1354,0$' '147,0$' '119,0$' '1413,0$' '452,0$' '334,0$'
#  '1132,0$' '982,0$' '480,0$' '1099,0$' '672,0$' '1379,0$' '583,0$'
#  '1492,0$' '1050,0$' '469,0$' '237,0$' '1440,0$' '1291,0$' '1157,0$'
#  '1336,0$' '1224,0$' '735,0$' '1389,0$' '638,0$' '1240,0$' '194,0$'
#  '1339,0$' '111,0$' '1469,0$' '470,0$' '1232,0$' '1249,0$' '798,0$'
#  '289,0$' '955,0$' '660,0$' '415,0$' '309,0$' '130,0$' '862,0$' '1098,0$'
#  '969,0$' '373,0$' '599,0$' '968,0$' '830,0$' '1423,0$' '516,0$' '598,0$'
#  '104,0$' '479,0$' '474,0$' '264,0$' '1059,0$' '563,0$' '1259,0$' '369,0$'
#  '543,0$' '964,0$' '176,0$' '181,0$' '211,0$' '590,0$' '305,0$' '478,0$'
#  '1294,0$' '1128,0$' '726,0$' '352,0$' '1172,0$' '605,0$' '1337,0$'
#  '105,0$']
# SALARY ['1000000000$']

# %% [markdown]
# Tras comprobar los valores únicos constatamos que:
# * La columna AGE tiene cifras escritas con letras que debemos cambiar antes de transformar el tipo de dato.
# * La columna STANDARD_HOURS contiene el valor 80,0 o nan para todos los registros por lo que es inútil a efectos de análsis y ml, de modo que puede ser eliminada.
# * La columna SALARY contiene el mismo valor para todos los registros y es inútil a efectos de análsis y ml, de modo que puede ser eliminada.
# * Todos los valores de la columna NUMBER_CHILDREN son nulso y puede ser eliminada

# %%
# Eliminamos columnas
df_types = df_types.drop(['STANDARD_HOURS', 'SALARY', 'NUMBER_CHILDREN'], axis=1)

# %%
# Sacamos los valores escritos con letras de AGE

letras = [i for i in df['AGE'] if len(i)>2]
letras
# Out:
# ['forty-seven',
#  'fifty-eight',
#  'thirty-six',
#  'fifty-five',
#  'fifty-two',
#  'thirty-one',
#  'thirty',
#  'twenty-six',
#  'thirty-seven',
#  'thirty-two',
#  'twenty-four',
#  'thirty-two']

# %%
# Creamos un diccionario con los valores a sustituir

dict_num = {'forty-seven': '47',
 'fifty-eight': '58',
 'thirty-six': '36',
 'fifty-five': '55',
 'fifty-two': '52',
 'thirty-one': '31',
 'thirty': '30',
 'twenty-six': '26',
 'thirty-seven': '37',
 'thirty-two': '32',
 'twenty-four': '24'}

# %%
# Aplicamos map al diccionario que acabamos de crear

df_types['AGE'] = df_types['AGE'].replace(dict_num)

# %%
df_types['AGE'].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', '53', '43', '60', '32',
#        '37', '49', '39', '50', '44', '30', '29', '31', '54', '57', '27',
#        '28', '26', '25', '24', '23', '22', '21', '20', '19', '18'],
#       dtype=object)

# %% [markdown]
# Ahora vamos a sustituir la coma por punto y cambiar el dato a entero

# %%
num_coma = ['TOTAL_WORKING_YEARS', 'WORK_LIFE_BALANCE', 'YEARS_IN_CURRENT_ROLE', 'MONTHLY_INCOME', 'PERFORMANCE_RATING']

# %%
for column in num_coma:
    df_types[column] = df_types[column].apply(lambda x: int(x.replace(',', '')) if pd.notna(x) else x)

# %% [markdown]
# Pasamos 'AGE' y 'HOURLY_RATE'  a entero, sustituyendo los 'Not Available' de 'HOURLY_RATE' por NaN

# %%
df_types[['AGE', 'HOURLY_RATE']] = df_types[['AGE', 'HOURLY_RATE']].replace('Not Available', np.nan).apply(pd.to_numeric).astype('Int64')

# %% [markdown]
# Tan solo falta cambiar 'DAILY_RATE', que además de la coma tiene el símbolo del dollar

# %%
df_types['DAILY_RATE'] = df_types['DAILY_RATE'].apply(lambda x: str(x).replace('$', ''))

# %%
df_types['DAILY_RATE'] = df_types['DAILY_RATE'].replace('nan', np.nan).apply(lambda x: int(str(x).replace(',', '')) if pd.notna(x) else x)

# %% [markdown]
# Siguiendo con el estudio de los datos vemos que hay otras cinco columnas que pueden ser eliminadas:
# * 'OVER_18' tiene nulos y su información puede ser obtenida de la columna 'AGE', que ahora que ya está con sus datos en enteros, podemos comprobar que todos los empleados son mayores de edad, ya que su valor mínimo es 18.
# * Las columnas 'DEPARTMENT', 'ROLE_DEPARTAMENT' y 'YEARS_IN_CURRENT_ROLE' tienen tal cantidad de nulos, que no merece la pena mantenerlas
# * 'EMPLOYEE_COUNT' contiene el valor 1 para todas las filas

# %%
# Comprobamos la edad mínima de los empleados
print(df_types['AGE'].min())
# Out:
# 18

# %%
# Eliminamos la columnas indeseadas
df_types = df_types.drop(['DEPARTMENT', 'ROLE_DEPARTAMENT', 'YEARS_IN_CURRENT_ROLE', 'OVER_18', 'EMPLOYEE_COUNT'], axis=1)

# %%
#Comprobamos que los datos han cambiado correctamente
df_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AGE                         1614 non-null   Int64
#  1   ATTRITION                   1614 non-null   object
#  2   BUSINESS_TRAVEL             842 non-null    object
#  3   DAILY_RATE                  1490 non-null   float64
#  4   DISTANCE_FROM_HOME          1614 non-null   int64
#  5   EDUCATION                   1614 non-null   int64
#  6   EDUCATION_FIELD             869 non-null    object
#  7   ENVIRONMENT_SATISFACTION    1614 non-null   int64
#  8   GENDER                      1614 non-null   int64
#  9   HOURLY_RATE                 1530 non-null   Int64
#  10  JOB_INVOLVEMENT             1614 non-null   int64
#  11  JOB_LEVEL                   1614 non-null   int64
#  12  JOB_ROLE                    1614 non-null   object
#  13  JOB_SATISFACTION            1614 non-null   int64
#  14  MARITAL_STATUS              963 non-null    object
#  15  MONTHLY_INCOME              771 non-null    float64
#  16  MONTHLY_RATE                1614 non-null   int64
#  17  NUM_COMPANIES_WORKED        1614 non-null   int64
#  18  OVER_TIME                   938 non-null    object
#  19  PERCENT_SALARY_HIKE         1614 non-null   int64
#  20  PERFORMANCE_RATING          1419 non-null   float64
#  21  RELATIONSHIP_SATISFACTION   1614 non-null   int64
#  22  STOCK_OPTION_LEVEL          1614 non-null   int64
#  23  TOTAL_WORKING_YEARS         1088 non-null   float64
#  24  TRAINING_TIMES_LAST_YEAR    1614 non-null   int64
#  25  WORK_LIFE_BALANCE           1506 non-null   float64
#  26  YEARS_AT_COMPANY            1614 non-null   int64
#  27  YEARS_SINCE_LAST_PROMOTION  1614 non-null   int64
#  28  YEARS_WITH_CURR_MANAGER     1614 non-null   int64
#  29  DATE_BIRTH                  1614 non-null   int64
#  30  REMOTE_WORK                 1614 non-null   object
# dtypes: Int64(2), float64(5), int64(17), object(7)
# memory usage: 406.7+ KB

# %% [markdown]
# Vamos a ver una descripción de los datos numéricos

# %%
df_types.describe().T
# Out:
#                              count          mean           std      min  \
# AGE                         1614.0     36.920694      9.102157     18.0
# DAILY_RATE                  1490.0   8020.852349   4032.469544   1030.0
# DISTANCE_FROM_HOME          1614.0      4.527261     14.591913    -49.0
# EDUCATION                   1614.0      2.925031      1.022357      1.0
# ENVIRONMENT_SATISFACTION    1614.0      4.294919      6.993559      1.0
# GENDER                      1614.0      0.398389      0.489718      0.0
# HOURLY_RATE                 1530.0     66.028105     20.185954     30.0
# JOB_INVOLVEMENT             1614.0      2.739777      0.711567      1.0
# JOB_LEVEL                   1614.0      2.068154      1.101344      1.0
# JOB_SATISFACTION            1614.0      2.738538      1.106163      1.0
# MONTHLY_INCOME               771.0  64776.861219  47661.199589  10090.0
# MONTHLY_RATE                1614.0  14284.495663   7110.414585   2094.0
# NUM_COMPANIES_WORKED        1614.0      2.673482      2.506152      0.0
# PERCENT_SALARY_HIKE         1614.0     15.165428       3.64861     11.0
# PERFORMANCE_RATING          1419.0     31.508104      3.579902     30.0
# RELATIONSHIP_SATISFACTION   1614.0      2.704461      1.079031      1.0
# STOCK_OPTION_LEVEL          1614.0      0.791202      0.842396      0.0
# TOTAL_WORKING_YEARS         1088.0    113.189338     77.276746      0.0
# TRAINING_TIMES_LAST_YEAR    1614.0      2.809789      1.297765      0.0
# WORK_LIFE_BALANCE           1506.0     27.596282      7.026222     10.0
# YEARS_AT_COMPANY            1614.0       7.13259      6.124237      0.0
# YEARS_SINCE_LAST_PROMOTION  1614.0      2.245973      3.235665      0.0
# YEARS_WITH_CURR_MANAGER     1614.0       4.22057      3.562695      0.0
# DATE_BIRTH                  1614.0   1986.076208      9.101332   1963.0
#
#                                 25%      50%      75%       max
# AGE                            30.0     36.0     43.0      60.0
# DAILY_RATE                   4682.5   7980.0  11570.0   14990.0
# DISTANCE_FROM_HOME              2.0      5.0     11.0      29.0
# EDUCATION                       2.0      3.0      4.0       5.0
# ENVIRONMENT_SATISFACTION        2.0      3.0      4.0      49.0
# GENDER                          0.0      0.0      1.0       1.0
# HOURLY_RATE                    48.0     66.0     84.0     100.0
# JOB_INVOLVEMENT                 2.0      3.0      3.0       4.0
# JOB_LEVEL                       1.0      2.0      3.0       5.0
# JOB_SATISFACTION                2.0      3.0      4.0       4.0
# MONTHLY_INCOME              28800.0  48590.0  82305.0  199990.0
# MONTHLY_RATE                 8001.0  14248.5  20364.0   26999.0
# NUM_COMPANIES_WORKED            1.0      2.0      4.0       9.0
# PERCENT_SALARY_HIKE            12.0     14.0     18.0      25.0
# PERFORMANCE_RATING             30.0     30.0     30.0      40.0
# RELATIONSHIP_SATISFACTION       2.0      3.0      4.0       4.0
# STOCK_OPTION_LEVEL              0.0      1.0      1.0       3.0
# TOTAL_WORKING_YEARS            60.0    100.0    150.0     400.0
# TRAINING_TIMES_LAST_YEAR        2.0      3.0      3.0       6.0
# WORK_LIFE_BALANCE              20.0     30.0     30.0      40.0
# YEARS_AT_COMPANY                3.0      5.0      9.0      40.0
# YEARS_SINCE_LAST_PROMOTION      0.0      1.0      3.0      15.0
# YEARS_WITH_CURR_MANAGER         2.0      3.0      7.0      17.0
# DATE_BIRTH                   1980.0   1987.0   1993.0    2005.0

# %% [markdown]
# Podemos constatar que la columna 'DISTANCE_FROM_HOME' tiene valores negativos, lo cual no tiene mucho sentido, de modo que vamos a tomar el valor absoluto de sus cifras

# %%
df_types['DISTANCE_FROM_HOME'] = df_types['DISTANCE_FROM_HOME'].abs()

# %% [markdown]
# ## Columnas no numéricas
# Primero vamos a comprobar los valores únicos

# %%
for i in df_types.select_dtypes(exclude='number').columns:
    print(i, df_types[i].unique())
# Out:
# ATTRITION ['No' 'Yes']
# BUSINESS_TRAVEL [nan 'travel_rarely' 'travel_frequently' 'non-travel']
# EDUCATION_FIELD [nan 'Life Sciences' 'Technical Degree' 'Medical' 'Other' 'Marketing'
#  'Human Resources']
# JOB_ROLE [' resEArch DIREcToR ' ' ManAGeR ' ' ManaGER ' ... ' sAlES ExECUTivE '
#  ' SaLes ExecUtIVe ' ' mAnUfactURInG DiRECTOr ']
# MARITAL_STATUS [nan 'Married' 'Divorced' 'Single' 'divorced' 'Marreid']
# OVER_TIME ['No' nan 'Yes']
# REMOTE_WORK ['Yes' '1' 'False' '0' 'True']

# %% [markdown]
# De la ejecución anterior, podemos inferir la necesidad de realizar varias acciones:
# * En 'EDUCATION_FIELD' se sustituirán los espacios por _ y se pondrá todo en minúsculas.
# * En 'JOB_ROLE' se eliminarán los espacios del principio y el final, se sustituirán los espacios centrales por _ y se pondrá todo en minúsculas.
# * En 'MARITAL_STATUS' se pondrá todo en minúsculas y se cambiará 'marreid' por 'married'.
# * En 'REMOTE_WORK' se sustituirán 'False' y '0' por 'No', y '1' por 'Yes'.

# %%
# Realizamos los cambios propuestos en 'EDUCATION_FIELD'
df_types['EDUCATION_FIELD'] = df_types['EDUCATION_FIELD'].str.replace(' ', '_').str.lower()

# %%
# Realizamos los cambios propuestos en 'JOB_ROLE'
df_types['JOB_ROLE'] = df_types['JOB_ROLE'].str.strip().str.replace(' ', '_').str.lower()

# %%
# Realizamos los cambios propuestos en 'MARITAL_STATUS'
df_types['MARITAL_STATUS'] = df_types['MARITAL_STATUS'].str.replace('Marreid', 'Married').str.lower()

# %%
# Realizamos los cambios propuestos en 'REMOTE_WORK'
remote = {'False': 'No',
          '0': 'No',
          '1': 'yes',
          'True': 'yes'} 

df_types['REMOTE_WORK'] = df_types['REMOTE_WORK'].replace(remote).str.lower()

# %%
df_types['REMOTE_WORK'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# ## Visualización de los datos categóricos y numéricos

# %%
# Función para guardar las imágenes que se vayan generando

PROJECT_ROOT_DIR = "."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=100):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# Visualizacion de los datos categóricos

fig, axes = plt.subplots(4, 2, figsize = (25,35))

axes = axes.flat

columnas_object = df_types.select_dtypes(include = "object").columns

for i, colum in enumerate(columnas_object):
    df_types[colum].value_counts().plot.barh(ax = axes[i])
    axes[i].set_title(colum, fontsize = 20, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")

save_fig("categorical_plots")  
fig.tight_layout();
# Out:
# Saving figure categorical_plots

# %%
df_types.hist(bins = 50, figsize = (20,15))
save_fig("numerical_plots")
plt.show()
# Out:
# Saving figure numerical_plots

# %%
# Visualizacion de los datos numéricos
mask = np.triu(np.ones_like(df_types.select_dtypes(include='number').corr(), dtype = bool))
plt.figure(figsize=(30,20))
sns.heatmap(df_types.select_dtypes(include='number').corr(), 
           cmap = "YlGnBu", 
            mask = mask,
           annot = True)
save_fig("corr_heatmap")
plt.show();
# Out:
# Saving figure corr_heatmap
